# %%
# We willl be working with a famous titanic data set for these exercises. Later on in the Machine 
# Learning section, we will revisit this data, adn use it to predict survival rates of passangers. 
# For now we will focus on the visualization of the data with seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('whitegrid')

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# ## Titanic Data Visualization Task
#
# Recreate the plots below using the **Titanic** dataframe.
#
# There are very few hints, since most of the plots can be created with just one or two lines of code — a hint would basically give away the solution.
#
# Pay close attention to the **x** and **y** labels in each plot, as they may offer subtle hints.

# %%
sns.jointplot(x='fare', y='age',data=titanic)

# %%
sns.displot(titanic['fare'],kde=False,color='red',bins=20)

# %%
class_colors = {
    'First': 'blue',
    'Second': 'lightgreen',  
    'Third': 'red'    
    
}

sns.boxplot(x='class',y='age', data=titanic, palette='rainbow') # We can use the class_color for custom colors
# Out:
# C:\Users\liubo\AppData\Local\Temp\ipykernel_5460\2782008773.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='class',y='age', data=titanic, palette='rainbow') # We can use the class_color for custom colors
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.swarmplot(x='class',y='age', data=titanic,palette='Set2')
# Out:
# C:\Users\liubo\AppData\Local\Temp\ipykernel_5460\387414139.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='class',y='age', data=titanic,palette='Set2')
# <Axes: xlabel='class', ylabel='age'>
# C:\Users\liubo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\seaborn\categorical.py:3399: UserWarning: 15.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
colors = {
    'male': 'lightblue',
    'female': 'lightgreen', 
}

sns.countplot(x='sex',data=titanic,palette=colors)
# Out:
# C:\Users\liubo\AppData\Local\Temp\ipykernel_5460\1325738344.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=titanic,palette=colors)
# <Axes: xlabel='sex', ylabel='count'>

# %%
# Convert boolean columns to integers (True -> 1, False -> 0)
titanic['adult_male'] = titanic['adult_male'].astype(int)
titanic['alone'] = titanic['alone'].astype(int)

# Select all numeric columns (now including converted boolean columns)
numeric_data = titanic.select_dtypes(include='number')

# Compute correlation matrix
corr_matrix = numeric_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Titanic Numeric & Boolean Features')
plt.show()
